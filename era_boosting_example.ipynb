# %% [markdown]
# <a href="https://colab.research.google.com/github/numerai/example-scripts/blob/master/era_boosting_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from xgboost import XGBRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
TRAINING_DATAPATH = 'https://numerai-public-datasets.s3-us-west-2.amazonaws.com/latest_numerai_training_data.csv.xz'
df = pd.read_csv(TRAINING_DATAPATH)
features = [c for c in df if c.startswith("feature")]

def ar1(x):
    return np.corrcoef(x[:-1], x[1:])[0,1]

def autocorr_penalty(x):
    n = len(x)
    p = ar1(x)
    return np.sqrt(1 + 2*np.sum([((n - i)/n)*p**i for i in range(1,n)]))

def smart_sharpe(x):
    return np.mean(x)/(np.std(x, ddof=1)*autocorr_penalty(x))

def spearmanr(target, pred):
    return np.corrcoef(
        target,
        pred.rank(pct=True, method="first")
    )[0, 1]

def era_boost_train(X, y, era_col, proportion=0.5, trees_per_step=10, num_iters=200):
    model = XGBRegressor(max_depth=5, learning_rate=0.01, n_estimators=trees_per_step, n_jobs=-1, colsample_bytree=0.1)
    features = X.columns
    model.fit(X, y)
    new_df = X.copy()
    new_df["target"] = y
    new_df["era"] = era_col
    for i in range(num_iters-1):
        print(f"iteration {i}")
        # score each era
        print("predicting on train")
        preds = model.predict(X)
        new_df["pred"] = preds
        era_scores = pd.Series(index=new_df["era"].unique())
        print("getting per era scores")
        for era in new_df["era"].unique():
            era_df = new_df[new_df["era"] == era]
            era_scores[era] = spearmanr(era_df["target"], era_df["pred"])
        era_scores.sort_values(inplace=True)
        worst_eras = era_scores[era_scores <= era_scores.quantile(proportion)].index
        print(list(worst_eras))
        worst_df = new_df[new_df["era"].isin(worst_eras)]
        era_scores.sort_index(inplace=True)
        era_scores.plot(kind="bar")
        print("performance over time")
        plt.show()
        print("autocorrelation")
        print(ar1(era_scores))
        print("mean correlation")
        print(np.mean(era_scores))
        print("sharpe")
        print(np.mean(era_scores)/np.std(era_scores))
        print("smart sharpe")
        print(smart_sharpe(era_scores))
        model.n_estimators += trees_per_step
        booster = model.get_booster()
        print("fitting on worst eras")
        model.fit(worst_df[features], worst_df["target"], xgb_model=booster)
    return model

boost_model = era_boost_train(df[features], df["target"], era_col=df["era"], proportion=0.5, trees_per_step=10, num_iters=20)
# Out:
# [19:20:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 0
# predicting on train
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# getting per era scores
# ['era103', 'era68', 'era91', 'era58', 'era60', 'era69', 'era41', 'era27', 'era112', 'era67', 'era85', 'era19', 'era65', 'era104', 'era89', 'era18', 'era42', 'era14', 'era49', 'era66', 'era84', 'era106', 'era40', 'era75', 'era33', 'era9', 'era119', 'era25', 'era107', 'era113', 'era50', 'era73', 'era74', 'era7', 'era57', 'era101', 'era100', 'era2', 'era110', 'era114', 'era71', 'era8', 'era26', 'era31', 'era82', 'era46', 'era118', 'era117', 'era88', 'era59', 'era29', 'era35', 'era21', 'era24', 'era13', 'era86', 'era62', 'era79', 'era70', 'era81']
# performance over time
# autocorrelation
# 0.19056347331593365
# mean correlation
# 0.06904305002044078
# sharpe
# 2.3394072131223305
# smart sharpe
# 1.9240690220670957
# fitting on worst eras
# [19:20:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 1
# predicting on train
# getting per era scores
# ['era34', 'era32', 'era56', 'era30', 'era3', 'era54', 'era37', 'era78', 'era28', 'era53', 'era36', 'era99', 'era105', 'era63', 'era11', 'era108', 'era116', 'era77', 'era83', 'era51', 'era4', 'era45', 'era94', 'era80', 'era90', 'era93', 'era102', 'era43', 'era15', 'era10', 'era72', 'era92', 'era97', 'era61', 'era42', 'era44', 'era91', 'era120', 'era98', 'era115', 'era76', 'era16', 'era87', 'era5', 'era12', 'era1', 'era111', 'era6', 'era64', 'era74', 'era47', 'era109', 'era25', 'era7', 'era20', 'era52', 'era96', 'era23', 'era48', 'era9']
# performance over time
# autocorrelation
# -0.16737907776919278
# mean correlation
# 0.07622352639933644
# sharpe
# 2.811446637288859
# smart sharpe
# 3.3103404647211874
# fitting on worst eras
# [19:21:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 2
# predicting on train
# getting per era scores
# ['era68', 'era103', 'era58', 'era60', 'era69', 'era104', 'era66', 'era41', 'era106', 'era91', 'era107', 'era73', 'era85', 'era67', 'era40', 'era112', 'era27', 'era101', 'era89', 'era18', 'era33', 'era50', 'era26', 'era113', 'era119', 'era100', 'era49', 'era17', 'era46', 'era55', 'era21', 'era31', 'era19', 'era84', 'era70', 'era114', 'era117', 'era62', 'era110', 'era118', 'era59', 'era65', 'era42', 'era75', 'era82', 'era32', 'era116', 'era57', 'era13', 'era9', 'era88', 'era14', 'era71', 'era102', 'era3', 'era79', 'era34', 'era87', 'era35', 'era39']
# performance over time
# autocorrelation
# 0.07521072267409357
# mean correlation
# 0.07730581832197374
# sharpe
# 1.9225643981567548
# smart sharpe
# 1.7766925069858786
# fitting on worst eras
# [19:21:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 3
# predicting on train
# getting per era scores
# ['era68', 'era103', 'era58', 'era66', 'era85', 'era60', 'era29', 'era81', 'era8', 'era91', 'era99', 'era86', 'era74', 'era106', 'era41', 'era100', 'era19', 'era69', 'era50', 'era46', 'era28', 'era104', 'era54', 'era80', 'era78', 'era93', 'era40', 'era53', 'era18', 'era24', 'era117', 'era49', 'era67', 'era56', 'era89', 'era25', 'era37', 'era95', 'era119', 'era107', 'era98', 'era63', 'era5', 'era27', 'era45', 'era22', 'era82', 'era31', 'era2', 'era84', 'era26', 'era9', 'era34', 'era97', 'era112', 'era114', 'era7', 'era55', 'era43', 'era111']
# performance over time
# autocorrelation
# 0.0012629639878276196
# mean correlation
# 0.0911637053798566
# sharpe
# 5.481831258880421
# smart sharpe
# 5.452109793286549
# fitting on worst eras
# [19:21:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 4
# predicting on train
# getting per era scores
# ['era68', 'era103', 'era32', 'era11', 'era58', 'era65', 'era14', 'era75', 'era59', 'era35', 'era3', 'era21', 'era57', 'era51', 'era118', 'era42', 'era91', 'era116', 'era15', 'era94', 'era77', 'era85', 'era33', 'era101', 'era73', 'era44', 'era79', 'era113', 'era110', 'era1', 'era96', 'era52', 'era70', 'era81', 'era17', 'era90', 'era109', 'era47', 'era36', 'era10', 'era49', 'era72', 'era66', 'era106', 'era40', 'era9', 'era41', 'era50', 'era12', 'era13', 'era29', 'era62', 'era120', 'era61', 'era115', 'era20', 'era100', 'era102', 'era30', 'era8']
# performance over time
# autocorrelation
# -0.10091594322834774
# mean correlation
# 0.09846038217708765
# sharpe
# 6.869412013093646
# smart sharpe
# 7.563288793612459
# fitting on worst eras
# [19:22:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 5
# predicting on train
# getting per era scores
# ['era68', 'era60', 'era103', 'era69', 'era19', 'era74', 'era58', 'era119', 'era7', 'era71', 'era80', 'era107', 'era84', 'era67', 'era117', 'era46', 'era91', 'era89', 'era112', 'era104', 'era34', 'era78', 'era25', 'era18', 'era54', 'era114', 'era4', 'era82', 'era55', 'era42', 'era31', 'era86', 'era27', 'era99', 'era88', 'era21', 'era108', 'era93', 'era75', 'era38', 'era53', 'era98', 'era6', 'era3', 'era23', 'era57', 'era26', 'era45', 'era85', 'era113', 'era41', 'era66', 'era87', 'era56', 'era101', 'era76', 'era116', 'era97', 'era33', 'era37']
# performance over time
# autocorrelation
# 0.04981221444548435
# mean correlation
# 0.10311402013396469
# sharpe
# 6.534276831179925
# smart sharpe
# 6.193128605297869
# fitting on worst eras
# [19:22:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 6
# predicting on train
# getting per era scores
# ['era65', 'era59', 'era9', 'era32', 'era35', 'era81', 'era68', 'era63', 'era64', 'era11', 'era111', 'era39', 'era2', 'era118', 'era106', 'era40', 'era79', 'era70', 'era7', 'era103', 'era14', 'era49', 'era50', 'era51', 'era94', 'era117', 'era77', 'era110', 'era83', 'era28', 'era24', 'era36', 'era48', 'era29', 'era95', 'era119', 'era107', 'era92', 'era52', 'era43', 'era100', 'era58', 'era34', 'era60', 'era53', 'era25', 'era46', 'era47', 'era84', 'era44', 'era18', 'era17', 'era96', 'era91', 'era42', 'era22', 'era62', 'era69', 'era15', 'era102']
# performance over time
# autocorrelation
# 0.035587477887545314
# mean correlation
# 0.11088895529563943
# sharpe
# 8.615414467940663
# smart sharpe
# 8.281825108332987
# fitting on worst eras
# [19:23:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 7
# predicting on train
# getting per era scores
# ['era19', 'era103', 'era80', 'era74', 'era67', 'era68', 'era114', 'era12', 'era73', 'era41', 'era89', 'era66', 'era85', 'era54', 'era71', 'era75', 'era3', 'era112', 'era27', 'era55', 'era82', 'era100', 'era101', 'era31', 'era57', 'era8', 'era21', 'era91', 'era90', 'era115', 'era7', 'era99', 'era104', 'era113', 'era35', 'era60', 'era16', 'era87', 'era116', 'era2', 'era78', 'era105', 'era14', 'era33', 'era32', 'era9', 'era10', 'era88', 'era93', 'era98', 'era58', 'era108', 'era4', 'era43', 'era70', 'era45', 'era1', 'era72', 'era107', 'era109']
# performance over time
# autocorrelation
# 0.09680482207056058
# mean correlation
# 0.11190238782394825
# sharpe
# 8.405774229706095
# smart sharpe
# 7.602223952290934
# fitting on worst eras
# [19:24:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 8
# predicting on train
# getting per era scores
# ['era65', 'era59', 'era40', 'era81', 'era69', 'era50', 'era111', 'era5', 'era110', 'era106', 'era117', 'era13', 'era26', 'era49', 'era39', 'era34', 'era18', 'era11', 'era79', 'era46', 'era53', 'era86', 'era84', 'era118', 'era25', 'era37', 'era119', 'era42', 'era47', 'era61', 'era68', 'era120', 'era63', 'era52', 'era56', 'era51', 'era89', 'era107', 'era6', 'era36', 'era28', 'era44', 'era57', 'era17', 'era103', 'era20', 'era94', 'era77', 'era9', 'era24', 'era38', 'era29', 'era32', 'era64', 'era19', 'era102', 'era97', 'era96', 'era112', 'era15']
# performance over time
# autocorrelation
# 0.00807034610554681
# mean correlation
# 0.12181267511411689
# sharpe
# 8.249787657165236
# smart sharpe
# 8.149854522735907
# fitting on worst eras
# [19:24:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 9
# predicting on train
# getting per era scores
# ['era91', 'era41', 'era66', 'era60', 'era85', 'era67', 'era68', 'era80', 'era104', 'era58', 'era73', 'era103', 'era69', 'era114', 'era101', 'era62', 'era54', 'era100', 'era7', 'era74', 'era55', 'era31', 'era27', 'era35', 'era23', 'era113', 'era75', 'era3', 'era33', 'era21', 'era71', 'era116', 'era40', 'era117', 'era87', 'era12', 'era22', 'era34', 'era19', 'era106', 'era70', 'era99', 'era82', 'era26', 'era84', 'era14', 'era65', 'era88', 'era49', 'era76', 'era30', 'era46', 'era48', 'era43', 'era98', 'era2', 'era10', 'era16', 'era78', 'era118']
# performance over time
# autocorrelation
# 0.09806512485409276
# mean correlation
# 0.12341863835760118
# sharpe
# 8.905984830206075
# smart sharpe
# 8.044461941861982
# fitting on worst eras
# [19:25:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 10
# predicting on train
# getting per era scores
# ['era81', 'era95', 'era25', 'era111', 'era59', 'era50', 'era83', 'era11', 'era9', 'era39', 'era92', 'era18', 'era56', 'era32', 'era109', 'era42', 'era79', 'era90', 'era53', 'era93', 'era63', 'era57', 'era110', 'era35', 'era37', 'era119', 'era89', 'era51', 'era13', 'era107', 'era47', 'era94', 'era29', 'era45', 'era5', 'era61', 'era41', 'era36', 'era1', 'era52', 'era65', 'era91', 'era86', 'era31', 'era17', 'era54', 'era112', 'era7', 'era96', 'era85', 'era120', 'era77', 'era8', 'era23', 'era105', 'era28', 'era72', 'era4', 'era102', 'era34']
# performance over time
# autocorrelation
# 0.06080064476339463
# mean correlation
# 0.13507749460506374
# sharpe
# 10.910114003486044
# smart sharpe
# 10.228103768232755
# fitting on worst eras
# [19:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 11
# predicting on train
# getting per era scores
# ['era68', 'era69', 'era60', 'era103', 'era58', 'era104', 'era67', 'era66', 'era73', 'era40', 'era21', 'era101', 'era27', 'era114', 'era62', 'era113', 'era91', 'era55', 'era80', 'era87', 'era3', 'era33', 'era100', 'era74', 'era75', 'era41', 'era106', 'era84', 'era107', 'era116', 'era70', 'era44', 'era88', 'era97', 'era115', 'era46', 'era71', 'era117', 'era26', 'era6', 'era19', 'era108', 'era49', 'era12', 'era38', 'era112', 'era22', 'era15', 'era119', 'era9', 'era14', 'era85', 'era42', 'era18', 'era24', 'era50', 'era82', 'era7', 'era20', 'era89']
# performance over time
# autocorrelation
# 0.10118176790406452
# mean correlation
# 0.13308254654930052
# sharpe
# 7.252120710884461
# smart sharpe
# 6.530171764681238
# fitting on worst eras
# [19:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 12
# predicting on train
# getting per era scores
# ['era81', 'era78', 'era32', 'era64', 'era99', 'era30', 'era39', 'era65', 'era111', 'era93', 'era95', 'era35', 'era53', 'era63', 'era11', 'era59', 'era37', 'era57', 'era76', 'era56', 'era25', 'era45', 'era34', 'era54', 'era79', 'era92', 'era90', 'era10', 'era31', 'era83', 'era47', 'era29', 'era40', 'era2', 'era51', 'era69', 'era36', 'era21', 'era114', 'era118', 'era94', 'era116', 'era4', 'era98', 'era48', 'era13', 'era110', 'era16', 'era8', 'era43', 'era28', 'era1', 'era5', 'era105', 'era23', 'era86', 'era58', 'era80', 'era102', 'era109']
# performance over time
# autocorrelation
# 0.036655273098730644
# mean correlation
# 0.14982115486770964
# sharpe
# 12.688791229155695
# smart sharpe
# 12.184554932875534
# fitting on worst eras
# [19:28:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 13
# predicting on train
# getting per era scores
# ['era68', 'era60', 'era103', 'era104', 'era91', 'era67', 'era69', 'era41', 'era66', 'era58', 'era73', 'era27', 'era107', 'era33', 'era17', 'era113', 'era106', 'era101', 'era62', 'era3', 'era75', 'era70', 'era117', 'era84', 'era100', 'era46', 'era40', 'era18', 'era9', 'era87', 'era112', 'era74', 'era72', 'era55', 'era49', 'era44', 'era42', 'era119', 'era26', 'era50', 'era88', 'era71', 'era19', 'era97', 'era85', 'era15', 'era61', 'era52', 'era6', 'era32', 'era115', 'era22', 'era38', 'era14', 'era89', 'era12', 'era81', 'era108', 'era7', 'era24']
# performance over time
# autocorrelation
# 0.08117139245359586
# mean correlation
# 0.1454708017643731
# sharpe
# 8.405798480595836
# smart sharpe
# 7.721963279197698
# fitting on worst eras
# [19:29:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 14
# predicting on train
# getting per era scores
# ['era77', 'era96', 'era65', 'era120', 'era39', 'era59', 'era35', 'era82', 'era111', 'era53', 'era10', 'era99', 'era34', 'era57', 'era11', 'era116', 'era93', 'era78', 'era25', 'era30', 'era54', 'era20', 'era56', 'era21', 'era114', 'era79', 'era95', 'era63', 'era64', 'era2', 'era37', 'era29', 'era45', 'era90', 'era31', 'era47', 'era110', 'era36', 'era4', 'era80', 'era51', 'era60', 'era117', 'era68', 'era103', 'era81', 'era13', 'era92', 'era76', 'era102', 'era91', 'era32', 'era48', 'era46', 'era98', 'era94', 'era16', 'era43', 'era106', 'era5']
# performance over time
# autocorrelation
# 0.07013180122499489
# mean correlation
# 0.1624429872487469
# sharpe
# 14.048830653580088
# smart sharpe
# 13.04879227453485
# fitting on worst eras
# [19:30:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 15
# predicting on train
# getting per era scores
# ['era68', 'era104', 'era69', 'era60', 'era67', 'era103', 'era107', 'era41', 'era66', 'era27', 'era118', 'era40', 'era58', 'era33', 'era113', 'era101', 'era70', 'era62', 'era28', 'era73', 'era17', 'era9', 'era3', 'era87', 'era75', 'era84', 'era100', 'era112', 'era1', 'era74', 'era55', 'era72', 'era88', 'era44', 'era18', 'era71', 'era119', 'era19', 'era50', 'era49', 'era85', 'era12', 'era42', 'era86', 'era97', 'era6', 'era8', 'era26', 'era52', 'era14', 'era7', 'era59', 'era21', 'era91', 'era15', 'era89', 'era115', 'era61', 'era83', 'era10']
# performance over time
# autocorrelation
# 0.1630503196177299
# mean correlation
# 0.16103749927638536
# sharpe
# 11.517973198959853
# smart sharpe
# 9.743531774916525
# fitting on worst eras
# [19:31:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 16
# predicting on train
# getting per era scores
# ['era105', 'era39', 'era96', 'era35', 'era116', 'era65', 'era24', 'era109', 'era11', 'era23', 'era53', 'era77', 'era25', 'era111', 'era82', 'era120', 'era78', 'era30', 'era29', 'era38', 'era34', 'era56', 'era95', 'era79', 'era99', 'era93', 'era57', 'era32', 'era54', 'era117', 'era22', 'era114', 'era64', 'era108', 'era2', 'era45', 'era63', 'era31', 'era47', 'era81', 'era110', 'era20', 'era51', 'era90', 'era4', 'era102', 'era80', 'era106', 'era5', 'era36', 'era3', 'era92', 'era37', 'era9', 'era76', 'era46', 'era43', 'era1', 'era48', 'era17']
# performance over time
# autocorrelation
# 0.21615710136544933
# mean correlation
# 0.17728037415602016
# sharpe
# 11.394617561430895
# smart sharpe
# 9.126925005858286
# fitting on worst eras
# [19:33:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 17
# predicting on train
# getting per era scores
# ['era68', 'era69', 'era103', 'era60', 'era58', 'era107', 'era104', 'era40', 'era41', 'era67', 'era62', 'era113', 'era27', 'era73', 'era66', 'era91', 'era70', 'era33', 'era101', 'era16', 'era88', 'era75', 'era87', 'era55', 'era112', 'era13', 'era74', 'era89', 'era21', 'era119', 'era18', 'era19', 'era84', 'era100', 'era28', 'era94', 'era7', 'era98', 'era118', 'era49', 'era42', 'era71', 'era85', 'era59', 'era50', 'era12', 'era10', 'era26', 'era6', 'era44', 'era72', 'era52', 'era97', 'era65', 'era114', 'era14', 'era106', 'era8', 'era116', 'era86']
# performance over time
# autocorrelation
# 0.20368991871805295
# mean correlation
# 0.16966177885855122
# sharpe
# 9.202598118756194
# smart sharpe
# 7.467024260732863
# fitting on worst eras
# [19:34:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# iteration 18
# predicting on train
# getting per era scores
# ['era39', 'era35', 'era96', 'era53', 'era24', 'era29', 'era111', 'era61', 'era11', 'era105', 'era117', 'era34', 'era15', 'era32', 'era77', 'era25', 'era47', 'era23', 'era79', 'era99', 'era54', 'era82', 'era57', 'era78', 'era31', 'era56', 'era64', 'era30', 'era83', 'era120', 'era81', 'era2', 'era109', 'era93', 'era63', 'era38', 'era3', 'era115', 'era107', 'era9', 'era102', 'era110', 'era70', 'era22', 'era51', 'era95', 'era46', 'era5', 'era90', 'era45', 'era80', 'era43', 'era108', 'era92', 'era40', 'era17', 'era27', 'era69', 'era13', 'era1']
# performance over time
# autocorrelation
# 0.11689719155675654
# mean correlation
# 0.19118296172904847
# sharpe
# 14.7134728481647
# smart sharpe
# 13.041466610798759
# fitting on worst eras
# [19:36:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
